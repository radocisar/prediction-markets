# %%
import pandas as pd
import json
from IPython.display import display

# %%
# events = pd.read_json('events.json')
# events = pd.read_json('fed.json')
with open("fed.json", "r") as f:
    # data = json.load(f)
    events = pd.json_normalize(
        json.load(f),
        record_path=["markets"],
        record_prefix="markets.",
        meta=[
            "id",
            "ticker",
            "slug",
            "title",
            "description",
            "resolutionSource",
            "startDate",
            "creationDate",
            "endDate",
            "image",
            "icon",
            "active",
            "closed",
            "archived",
            "new",
            "featured",
            "restricted",
            "liquidity",
            "volume",
            "openInterest",
            "createdAt",
            "updatedAt",
            "competitive",
            "volume24hr",
            "volume1wk",
            "volume1mo",
            "volume1yr",
            "enableOrderBook",
            "liquidityClob",
            "negRisk",
            "negRiskMarketID",
            "commentCount",
            "series",
            "tags",
            "cyom",
            "showAllOutcomes",
            "showMarketImages",
            "enableNegRisk",
            "automaticallyActive",
            "seriesSlug",
            "gmpChartMode",
            "negRiskAugmented",
            "featuredOrder",
            "estimateValue",
            "cumulativeMarkets",
            "pendingDeployment",
            "deploying",
            "deployingTimestamp",
            "requiresTranslation",
        ],
    )
events.head()
# Out:
#   markets.id                                   markets.question  \
# 0     654412  Will the Fed decrease interest rates by 50+ bp...
# 1     654413  Will the Fed decrease interest rates by 25 bps...
# 2     654414  Will there be no change in Fed interest rates ...
# 3     654415  Will the Fed increase interest rates by 25+ bp...
#
#                                  markets.conditionId  \
# 0  0xdeb615a52cd114e5aa27d8344ae506a72bea81f6ed13...
# 1  0xd6c49a94948e365aa74c09eef54d907b7ca534b243c3...
# 2  0x257b18205f908aef01ef2d1d50e6fea7d29cf5486fe0...
# 3  0x25aa90b3cd98305e849189b4e8b770fc77fe89bccb7c...
#
#                                         markets.slug markets.resolutionSource  \
# 0  will-the-fed-decrease-interest-rates-by-50-bps...
# 1  will-the-fed-decrease-interest-rates-by-25-bps...
# 2  will-there-be-no-change-in-fed-interest-rates-...
# 3  will-the-fed-increase-interest-rates-by-25-bps...
#
#         markets.endDate markets.liquidity            markets.startDate  \
# 0  2026-03-18T00:00:00Z     1255318.53266  2025-10-29T19:01:04.738799Z
# 1  2026-03-18T00:00:00Z        621069.767  2025-10-29T19:01:04.993149Z
# 2  2026-03-18T00:00:00Z       917613.8292  2025-10-29T19:01:07.998079Z
# 3  2026-03-18T00:00:00Z     1666762.87334  2025-10-29T19:01:07.490058Z
#
#                                        markets.image  \
# 0  https://polymarket-upload.s3.us-east-2.amazona...
# 1  https://polymarket-upload.s3.us-east-2.amazona...
# 2  https://polymarket-upload.s3.us-east-2.amazona...
# 3  https://polymarket-upload.s3.us-east-2.amazona...
#
#                                         markets.icon  ... seriesSlug  \
# 0  https://polymarket-upload.s3.us-east-2.amazona...  ...       fomc
# 1  https://polymarket-upload.s3.us-east-2.amazona...  ...       fomc
# 2  https://polymarket-upload.s3.us-east-2.amazona...  ...       fomc
# 3  https://polymarket-upload.s3.us-east-2.amazona...  ...       fomc
#
#   gmpChartMode negRiskAugmented featuredOrder  estimateValue  \
# 0      default            False             1          False
# 1      default            False             1          False
# 2      default            False             1          False
# 3      default            False             1          False
#
#    cumulativeMarkets pendingDeployment deploying           deployingTimestamp  \
# 0              False             False     False  2025-10-29T18:51:42.034149Z
# 1              False             False     False  2025-10-29T18:51:42.034149Z
# 2              False             False     False  2025-10-29T18:51:42.034149Z
# 3              False             False     False  2025-10-29T18:51:42.034149Z
#
#    requiresTranslation
# 0                False
# 1                False
# 2                False
# 3                False
#
# [4 rows x 136 columns]

# %%
events.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 136 columns):
#  #    Column                                Dtype
# ---   ------                                -----
#  0    markets.id                            str
#  1    markets.question                      str
#  2    markets.conditionId                   str
#  3    markets.slug                          str
#  4    markets.resolutionSource              str
#  5    markets.endDate                       str
#  6    markets.liquidity                     str
#  7    markets.startDate                     str
#  8    markets.image                         str
#  9    markets.icon                          str
#  10   markets.description                   str
#  11   markets.outcomes                      str
#  12   markets.outcomePrices                 str
#  13   markets.volume                        str
#  14   markets.active                        bool
#  15   markets.closed                        bool
#  16   markets.marketMakerAddress            str
#  17   markets.createdAt                     str
#  18   markets.updatedAt                     str
#  19   markets.new                           bool
#  20   markets.featured                      bool
#  21   markets.submitted_by                  str
#  22   markets.archived                      bool
#  23   markets.resolvedBy                    str
#  24   markets.restricted                    bool
#  25   markets.groupItemTitle                str
#  26   markets.groupItemThreshold            str
#  27   markets.questionID                    str
#  28   markets.enableOrderBook               bool
#  29   markets.orderPriceMinTickSize         float64
#  30   markets.orderMinSize                  int64
#  31   markets.volumeNum                     float64
#  32   markets.liquidityNum                  float64
#  33   markets.endDateIso                    str
#  34   markets.startDateIso                  str
#  35   markets.hasReviewedDates              bool
#  36   markets.volume24hr                    float64
#  37   markets.volume1wk                     float64
#  38   markets.volume1mo                     float64
#  39   markets.volume1yr                     float64
#  40   markets.clobTokenIds                  str
#  41   markets.umaBond                       str
#  42   markets.umaReward                     str
#  43   markets.volume24hrClob                float64
#  44   markets.volume1wkClob                 float64
#  45   markets.volume1moClob                 float64
#  46   markets.volume1yrClob                 float64
#  47   markets.volumeClob                    float64
#  48   markets.liquidityClob                 float64
#  49   markets.customLiveness                int64
#  50   markets.acceptingOrders               bool
#  51   markets.negRisk                       bool
#  52   markets.negRiskMarketID               str
#  53   markets.negRiskRequestID              str
#  54   markets.ready                         bool
#  55   markets.funded                        bool
#  56   markets.acceptingOrdersTimestamp      str
#  57   markets.cyom                          bool
#  58   markets.competitive                   float64
#  59   markets.pagerDutyNotificationEnabled  bool
#  60   markets.approved                      bool
#  61   markets.rewardsMinSize                int64
#  62   markets.rewardsMaxSpread              float64
#  63   markets.spread                        float64
#  64   markets.oneHourPriceChange            float64
#  65   markets.oneWeekPriceChange            float64
#  66   markets.oneMonthPriceChange           float64
#  67   markets.lastTradePrice                float64
#  68   markets.bestBid                       float64
#  69   markets.bestAsk                       float64
#  70   markets.automaticallyActive           bool
#  71   markets.clearBookOnStart              bool
#  72   markets.seriesColor                   str
#  73   markets.showGmpSeries                 bool
#  74   markets.showGmpOutcome                bool
#  75   markets.manualActivation              bool
#  76   markets.negRiskOther                  bool
#  77   markets.umaResolutionStatuses         str
#  78   markets.pendingDeployment             bool
#  79   markets.deploying                     bool
#  80   markets.deployingTimestamp            str
#  81   markets.rfqEnabled                    bool
#  82   markets.holdingRewardsEnabled         bool
#  83   markets.feesEnabled                   bool
#  84   markets.requiresTranslation           bool
#  85   markets.feeType                       object
#  86   markets.clobRewards                   object
#  87   id                                    str
#  88   ticker                                str
#  89   slug                                  str
#  90   title                                 str
#  91   description                           str
#  92   resolutionSource                      str
#  93   startDate                             str
#  94   creationDate                          str
#  95   endDate                               str
#  96   image                                 str
#  97   icon                                  str
#  98   active                                object
#  99   closed                                object
#  100  archived                              object
#  101  new                                   object
#  102  featured                              object
#  103  restricted                            object
#  104  liquidity                             object
#  105  volume                                object
#  106  openInterest                          object
#  107  createdAt                             str
#  108  updatedAt                             str
#  109  competitive                           object
#  110  volume24hr                            object
#  111  volume1wk                             object
#  112  volume1mo                             object
#  113  volume1yr                             object
#  114  enableOrderBook                       object
#  115  liquidityClob                         object
#  116  negRisk                               object
#  117  negRiskMarketID                       str
#  118  commentCount                          object
#  119  series                                object
#  120  tags                                  object
#  121  cyom                                  object
#  122  showAllOutcomes                       object
#  123  showMarketImages                      object
#  124  enableNegRisk                         object
#  125  automaticallyActive                   object
#  126  seriesSlug                            str
#  127  gmpChartMode                          str
#  128  negRiskAugmented                      object
#  129  featuredOrder                         object
#  130  estimateValue                         object
#  131  cumulativeMarkets                     object
#  132  pendingDeployment                     object
#  133  deploying                             object
#  134  deployingTimestamp                    str
#  135  requiresTranslation                   object
# dtypes: bool(27), float64(22), int64(3), object(34), str(50)
# memory usage: 3.6+ KB

# %%
events.melt(id_vars="id", var_name="columns", value_name="values")
# Out:
#         id              columns  \
# 0    67284           markets.id
# 1    67284           markets.id
# 2    67284           markets.id
# 3    67284           markets.id
# 4    67284     markets.question
# ..     ...                  ...
# 535  67284   deployingTimestamp
# 536  67284  requiresTranslation
# 537  67284  requiresTranslation
# 538  67284  requiresTranslation
# 539  67284  requiresTranslation
#
#                                                 values
# 0                                               654412
# 1                                               654413
# 2                                               654414
# 3                                               654415
# 4    Will the Fed decrease interest rates by 50+ bp...
# ..                                                 ...
# 535                        2025-10-29T18:51:42.034149Z
# 536                                              False
# 537                                              False
# 538                                              False
# 539                                              False
#
# [540 rows x 3 columns]

# %%
with pd.option_context("display.max_colwidth", None):
    display(events.melt(id_vars="id", var_name="columns", value_name="values"))
# Out:
#         id              columns  \
# 0    67284           markets.id
# 1    67284           markets.id
# 2    67284           markets.id
# 3    67284           markets.id
# 4    67284     markets.question
# ..     ...                  ...
# 535  67284   deployingTimestamp
# 536  67284  requiresTranslation
# 537  67284  requiresTranslation
# 538  67284  requiresTranslation
# 539  67284  requiresTranslation
#
#                                                                             values
# 0                                                                           654412
# 1                                                                           654413
# 2                                                                           654414
# 3                                                                           654415
# 4    Will the Fed decrease interest rates by 50+ bps after the March 2026 meeting?
# ..                                                                             ...
# 535                                                    2025-10-29T18:51:42.034149Z
# 536                                                                          False
# 537                                                                          False
# 538                                                                          False
# 539                                                                          False
#
# [540 rows x 3 columns]

# %%
# Markets
events["markets"].apply(
    pd.Series
)  # .melt(id_vars="id", var_name="columns", value_name="values")
# with pd.option_context("display.max_colwidth", None):
#     with pd.option_context("display.max_rows", None):
#         display(pd.json_normalize(events["markets"].apply(pd.Series)[0]).melt(id_vars="id", var_name="columns", value_name="values"))
# Out:
#                                                    0  \
# 0  {'id': '654412', 'question': 'Will the Fed dec...
#
#                                                    1  \
# 0  {'id': '654413', 'question': 'Will the Fed dec...
#
#                                                    2  \
# 0  {'id': '654414', 'question': 'Will there be no...
#
#                                                    3
# 0  {'id': '654415', 'question': 'Will the Fed inc...

# %%
# Series
with pd.option_context("display.max_colwidth", None):
    with pd.option_context("display.max_rows", None):
        display(
            pd.json_normalize(events["series"].apply(pd.Series)[0]).melt(
                id_vars="id", var_name="columns", value_name="values"
            )
        )
# Out:
#        id              columns                       values
# 0   10684               ticker            btc-up-or-down-5m
# 1   10684                 slug            btc-up-or-down-5m
# 2   10684                title            BTC Up or Down 5m
# 3   10684           seriesType                       single
# 4   10684           recurrence                           5m
# 5   10684                image
# 6   10684                 icon
# 7   10684               active                         True
# 8   10684               closed                        False
# 9   10684             archived                        False
# 10  10684             featured                        False
# 11  10684           restricted                         True
# 12  10684            createdAt  2025-11-21T21:46:22.201627Z
# 13  10684            updatedAt  2026-02-15T21:50:01.175953Z
# 14  10684           volume24hr              16799111.898786
# 15  10684               volume                 67790.025239
# 16  10684            liquidity                 1288429.8036
# 17  10684         commentCount                         5378
# 18  10684  requiresTranslation                        False

# %%
# Tags
with pd.option_context("display.max_colwidth", None):
    with pd.option_context("display.max_rows", None):
        display(
            pd.json_normalize(events["tags"].apply(pd.Series)[0]).melt(
                id_vars="id", var_name="columns", value_name="values"
            )
        )
# Out:
#        id              columns                       values
# 0  102127                label                   Up or Down
# 1  102127                 slug                   up-or-down
# 2  102127            forceShow                         True
# 3  102127            createdAt  2025-05-09T20:56:58.880785Z
# 4  102127            updatedAt  2026-02-06T19:59:13.276485Z
# 5  102127           isCarousel                        False
# 6  102127  requiresTranslation                        False
